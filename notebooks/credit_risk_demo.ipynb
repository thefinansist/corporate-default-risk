# %% [markdown]
# # Скрининг риска дефолта юридического лица
# Демонстрационный запуск объяснимой модели по бухгалтерской отчетности РСБУ. Индекс 0–100 не является откалиброванной PD.

# %%
from pathlib import Path
import sys
import pandas as pd
from IPython.display import display, HTML

PROJECT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_DIR / 'src'))
from credit_risk import analyze_path

# %%
INPUT_PATH = Path('/path/to/company.xlsx')
OUTPUT_DIR = PROJECT_DIR / 'results_jupyter'
COMPANY_NAME = 'Демонстрационная компания'
CONFIG_PATH = PROJECT_DIR / 'config' / 'scoring_config.json'

# %%
portfolio = analyze_path(INPUT_PATH, OUTPUT_DIR, CONFIG_PATH, COMPANY_NAME)
display(portfolio)

# %%
report_path = OUTPUT_DIR / 'Демонстрационная_компания' / 'report.html'
display(HTML(report_path.read_text(encoding='utf-8')))

# %% [markdown]
# ## Пакетная обработка
# Замените `INPUT_PATH` на папку с файлами разных компаний. Название компании будет взято из имени каждого Excel-файла.
